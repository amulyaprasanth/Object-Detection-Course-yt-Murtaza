# %% [markdown]
# # Project 3 - PPE Detection
#
# This notebook contains the code to detect ppe kits using YOLOv8 and custom training

# %%
# Checking for graphics card
# !nvidia-smi
# Out:
# Mon Oct 23 15:18:58 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.84                 Driver Version: 545.84       CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3070 ...  WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   63C    P0              31W / 115W |      0MiB /  8192MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
from ultralytics import YOLO

# %%
# Checking whether the model is working or not
# !yolo task=detect mode=predict model=yolov8s.pt conf=0.25 source="https://ultralytics.com/images/bus.jpg"
# Out:
# ...
#
#   0%|          | 0.00/21.5M [00:00<?, ?B/s]
#   7%|6         | 1.49M/21.5M [00:00<00:01, 14.5MB/s]
#  13%|#3        | 2.88M/21.5M [00:00<00:02, 8.78MB/s]
#  18%|#7        | 3.83M/21.5M [00:00<00:02, 7.85MB/s]
#  22%|##1       | 4.63M/21.5M [00:00<00:02, 7.25MB/s]
#  25%|##4       | 5.35M/21.5M [00:00<00:02, 6.51MB/s]
#  28%|##7       | 5.99M/21.5M [00:00<00:02, 6.24MB/s]
#  31%|###       | 6.59M/21.5M [00:01<00:03, 4.85MB/s]
#  33%|###2      | 7.09M/21.5M [00:01<00:03, 4.15MB/s]
#  35%|###4      | 7.52M/21.5M [00:01<00:03, 4.01MB/s]
#  37%|###6      | 7.93M/21.5M [00:01<00:03, 4.04MB/s]
#  39%|###8      | 8.38M/21.5M [00:01<00:03, 4.19MB/s]
#  41%|####1     | 8.90M/21.5M [00:01<00:02, 4.48MB/s]
#  44%|####3     | 9.46M/21.5M [00:01<00:02, 4.83MB/s]
#  47%|####6     | 10.1M/21.5M [00:01<00:02, 5.27MB/s]
#  50%|####9     | 10.7M/21.5M [00:02<00:01, 5.71MB/s]
#  53%|#####3    | 11.4M/21.5M [00:02<00:01, 6.17MB/s]
#  56%|#####6    | 12.1M/21.5M [00:02<00:01, 6.42MB/s]
# ...

# %% [markdown]
# ## Custom Data Training

# %%
# %pwd
# Out:
# 'D:\\Documents\\Object-Detection-Course-yt-Murtaza\\Object-Detection-YOLO\\Project 3 - PPE Detection'

# %%
import os
os.chdir("./data")

# %%
# %pwd
# Out:
# 'D:\\Documents\\Object-Detection-Course-yt-Murtaza\\Object-Detection-YOLO\\Project 3 - PPE Detection\\data'

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=data.yaml epochs=10 imgsz=640 cache=ram cache=disk
# Out:
# ...
#
#   0%|          | 0.00/21.5M [00:00<?, ?B/s]
#   6%|5         | 1.23M/21.5M [00:00<00:01, 11.8MB/s]
#  11%|#         | 2.36M/21.5M [00:00<00:01, 10.3MB/s]
#  16%|#5        | 3.35M/21.5M [00:00<00:02, 8.29MB/s]
#  19%|#9        | 4.18M/21.5M [00:00<00:02, 6.82MB/s]
#  23%|##2       | 4.87M/21.5M [00:00<00:03, 5.00MB/s]
#  25%|##5       | 5.41M/21.5M [00:00<00:03, 4.65MB/s]
#  27%|##7       | 5.90M/21.5M [00:01<00:03, 4.60MB/s]
#  30%|##9       | 6.38M/21.5M [00:01<00:03, 4.70MB/s]
#  32%|###2      | 6.91M/21.5M [00:01<00:03, 4.90MB/s]
#  35%|###4      | 7.51M/21.5M [00:01<00:02, 5.22MB/s]
#  38%|###7      | 8.15M/21.5M [00:01<00:02, 5.60MB/s]
#  41%|####1     | 8.84M/21.5M [00:01<00:02, 6.01MB/s]
#  44%|####4     | 9.57M/21.5M [00:01<00:01, 6.49MB/s]
#  48%|####8     | 10.4M/21.5M [00:01<00:01, 6.94MB/s]
#  52%|#####2    | 11.2M/21.5M [00:01<00:01, 7.48MB/s]
#  55%|#####5    | 11.9M/21.5M [00:01<00:01, 7.26MB/s]
#  59%|#####8    | 12.6M/21.5M [00:02<00:01, 5.59MB/s]
# ...
